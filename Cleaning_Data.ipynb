# %% [markdown]
# <a href="https://colab.research.google.com/github/IlliyyinAkbar2002/Scrape-Data-with-Transformer/blob/main/Cleaning_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
pf = pd.read_csv('sample_data/hk_project.csv')
pf.head()
# Out:
#    Unnamed: 0                              reviewId         userName  \
# 0           0  f84816b7-6c0c-4a13-a623-890548aee5dd  Pengguna Google
# 1           1  ec4cb706-2351-4ce6-a82e-d95e8359fdfc  Pengguna Google
# 2           2  c125f985-9d39-4137-b9d7-ce0b7c296a52  Pengguna Google
# 3           3  5086fc31-00c8-41d1-9ac2-84577181022a  Pengguna Google
# 4           4  2893e60c-52cd-4442-9a9c-1416dd6cee33  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content     score  thumbsUpCount  \
# 0                                               good  0.999696              0
# 1                       Semoga kedepannya lebih baik  0.999585              0
# 2  Pliss ini di perbaiki semua lagi kalau bisa di...  0.999680              0
# 3                                        Jelek skali  0.999839              0
# 4  Aplikasi jelek. Sekiranya mau bikin aplikasi y...  0.999857              0
#
#   reviewCreatedVersion                   at  replyContent  repliedAt  \
# 0                  NaN  2024-06-12 18:46:05           NaN        NaN
# 1                 2.52  2024-06-10 14:49:09           NaN        NaN
# 2                  NaN  2024-06-04 17:43:40           NaN        NaN
# 3                  NaN  2024-06-04 08:44:19           NaN        NaN
# 4                 2.52  2024-05-30 10:32:55           NaN        NaN
#
#   appVersion                                             result sentiment
# 0        NaN  [{'label': 'Positive', 'score': 0.999696254730...  Positive
# 1       2.52  [{'label': 'Positive', 'score': 0.999585211277...  Positive
# 2        NaN  [{'label': 'Neutral', 'score': 0.9996798038482...   Neutral
# 3        NaN  [{'label': 'Negative', 'score': 0.999839186668...  Negative
# 4       2.52  [{'label': 'Negative', 'score': 0.999856829643...  Negative

# %%
print(len(pf))
# Out:
# 19905

# %%
import re

# %%
def remove_pattern(Text, pattern):
    r = re.findall(pattern, str(Text))
    for i in r:
        Text = re.sub(i, '', str(Text))
    return Text
pf['remove_user'] = np.vectorize(remove_pattern)(pf['content'], "@[\w]*")

# %%
def cleaning(Text):
    Text = re.sub(r'\s&amp\s', ' ', Text)
    Text = re.sub(r'$\w*', '', Text)
    Text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', ' ', Text)
    Text = re.sub('"'," ", Text)
    Text = re.sub(r"\d+", " ", str(Text))
    Text = re.sub(r"[^\w\s]", " ", str(Text))
    Text = re.sub(r"\s+", " ", str(Text))
    Text = re.sub(r'#', '', Text)
    Text = re.sub(r'[^a-zA-z0-9]', ' ', str(Text))
    Text = re.sub(r'\s\s+', ' ', Text)
    Text = re.sub(r'^b[\s]+', '', Text)
    Text = re.sub(r'^link[\s]+', '', Text)
    return Text

def remove_emoji(Text):
    emoji = re.compile("["
                        u"\U0001F600-\U0001F64F"  # emoticons
                        u"\U0001F300-\U0001F5FF"  # simbol & piktogram
                        u"\U0001F680-\U0001F6FF"  # transportasi & simbol peralatan
                        u"\U0001F1E0-\U0001F1FF"  # bendera negara
                        u"\U00002702-\U000027B0"  # simbol
                        u"\U000024C2-\U0001F251"  # emoji lainnya
                        "]+", flags=re.UNICODE)
    return emoji.sub(r'', Text)

pf['cleaning'] = pf['remove_user'].apply(cleaning)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

def tokenize_with_quotes(text):
    tokens = word_tokenize(text)
    tokens_with_quotes = ['"' + token + '"' for token in tokens]
    return tokens_with_quotes

pf['tokenized_Content'] = pf['content'].apply(lambda x: tokenize_with_quotes(x))
pf
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#        Unnamed: 0                              reviewId           userName  \
# 0               0  f84816b7-6c0c-4a13-a623-890548aee5dd    Pengguna Google
# 1               1  ec4cb706-2351-4ce6-a82e-d95e8359fdfc    Pengguna Google
# 2               2  c125f985-9d39-4137-b9d7-ce0b7c296a52    Pengguna Google
# 3               3  5086fc31-00c8-41d1-9ac2-84577181022a    Pengguna Google
# 4               4  2893e60c-52cd-4442-9a9c-1416dd6cee33    Pengguna Google
# ...           ...                                   ...                ...
# 19900       19900  87663254-bc07-4c57-898b-7b43d7950263       aji prasetyo
# 19901       19901  f2e17df4-ffb3-45e1-a866-c72d3fae533b       Tn A Muntaha
# 19902       19902  10d1c67d-4f73-42fa-9e2f-cf7954ec929c    TATANG RUSDIANA
# 19903       19903  d128597e-09b5-48b6-857f-bd23cac547a5                vie
# 19904       19904  4ee68894-fdb9-4fc7-a614-c6448d903514  Ahmad ferdiansyah
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 3      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 19900  https://play-lh.googleusercontent.com/a-/ALV-U...
# 19901  https://play-lh.googleusercontent.com/a-/ALV-U...
# 19902  https://play-lh.googleusercontent.com/a-/ALV-U...
# 19903  https://play-lh.googleusercontent.com/a-/ALV-U...
# 19904  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                  content     score  \
# 0                                                   good  0.999696
# 1                           Semoga kedepannya lebih baik  0.999585
# 2      Pliss ini di perbaiki semua lagi kalau bisa di...  0.999680
# 3                                            Jelek skali  0.999839
# 4      Aplikasi jelek. Sekiranya mau bikin aplikasi y...  0.999857
# ...                                                  ...       ...
# 19900  Pemilu h-3 Minggu, aplikasi sepenting ini masi...  0.999799
# 19901  Semoga Tambah Baik,Mudah Dalam Input Dan Share...  0.986317
# 19902                                               Mbuh  0.999838
# 19903  Semoga tidak seperti sirekap 2020 yang saat di...  0.999579
# 19904  Semoga dengan adanya aplikasi ini pemilu akan ...  0.992004
#
#        thumbsUpCount reviewCreatedVersion                   at  replyContent  \
# 0                  0                  NaN  2024-06-12 18:46:05           NaN
# 1                  0                 2.52  2024-06-10 14:49:09           NaN
# 2                  0                  NaN  2024-06-04 17:43:40           NaN
# 3                  0                  NaN  2024-06-04 08:44:19           NaN
# 4                  0                 2.52  2024-05-30 10:32:55           NaN
# ...              ...                  ...                  ...           ...
# 19900           1296             2.17-STG  2024-01-23 14:00:36           NaN
# 19901             23                  NaN  2024-01-23 09:05:12           NaN
# 19902              6             2.17-STG  2024-01-23 07:03:12           NaN
# 19903             42                  NaN  2024-01-23 06:50:03           NaN
# 19904            188             2.17-STG  2024-01-23 04:26:11           NaN
#
#        repliedAt appVersion  \
# 0            NaN        NaN
# 1            NaN       2.52
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN       2.52
# ...          ...        ...
# 19900        NaN   2.17-STG
# 19901        NaN        NaN
# 19902        NaN   2.17-STG
# 19903        NaN        NaN
# 19904        NaN   2.17-STG
#
#                                                   result sentiment  \
# 0      [{'label': 'Positive', 'score': 0.999696254730...  Positive
# 1      [{'label': 'Positive', 'score': 0.999585211277...  Positive
# 2      [{'label': 'Neutral', 'score': 0.9996798038482...   Neutral
# 3      [{'label': 'Negative', 'score': 0.999839186668...  Negative
# 4      [{'label': 'Negative', 'score': 0.999856829643...  Negative
# ...                                                  ...       ...
# 19900  [{'label': 'Negative', 'score': 0.999798953533...  Negative
# 19901  [{'label': 'Neutral', 'score': 0.9863167405128...   Neutral
# 19902  [{'label': 'Negative', 'score': 0.999837994575...  Negative
# 19903  [{'label': 'Negative', 'score': 0.999578773975...  Negative
# 19904  [{'label': 'Neutral', 'score': 0.9920035004615...   Neutral
#
#                                              remove_user  \
# 0                                                   good
# 1                           Semoga kedepannya lebih baik
# 2      Pliss ini di perbaiki semua lagi kalau bisa di...
# 3                                            Jelek skali
# 4      Aplikasi jelek. Sekiranya mau bikin aplikasi y...
# ...                                                  ...
# 19900  Pemilu h-3 Minggu, aplikasi sepenting ini masi...
# 19901  Semoga Tambah Baik,Mudah Dalam Input Dan Share...
# 19902                                               Mbuh
# 19903  Semoga tidak seperti sirekap 2020 yang saat di...
# 19904  Semoga dengan adanya aplikasi ini pemilu akan ...
#
#                                                 cleaning  \
# 0                                                   good
# 1                           Semoga kedepannya lebih baik
# 2      Pliss ini di perbaiki semua lagi kalau bisa di...
# 3                                            Jelek skali
# 4      Aplikasi jelek Sekiranya mau bikin aplikasi ya...
# ...                                                  ...
# 19900  Pemilu h Minggu aplikasi sepenting ini masih t...
# 19901  Semoga Tambah Baik Mudah Dalam Input Dan Share...
# 19902                                               Mbuh
# 19903  Semoga tidak seperti sirekap yang saat digunak...
# 19904  Semoga dengan adanya aplikasi ini pemilu akan ...
#
#                                        tokenized_Content
# 0                                               ["good"]
# 1              ["Semoga", "kedepannya", "lebih", "baik"]
# 2      ["Pliss", "ini", "di", "perbaiki", "semua", "l...
# 3                                     ["Jelek", "skali"]
# 4      ["Aplikasi", "jelek", ".", "Sekiranya", "mau",...
# ...                                                  ...
# 19900  ["Pemilu", "h-3", "Minggu", ",", "aplikasi", "...
# 19901  ["Semoga", "Tambah", "Baik", ",", "Mudah", "Da...
# 19902                                           ["Mbuh"]
# 19903  ["Semoga", "tidak", "seperti", "sirekap", "202...
# 19904  ["Semoga", "dengan", "adanya", "aplikasi", "in...
#
# [19905 rows x 17 columns]

# %%
def calc_TF(document):
    # Counts the number of times the word appears in review
    TF_dict = {}
    for term in document:
        if term in TF_dict:
            TF_dict[term] += 1
        else:
            TF_dict[term] = 1
    # Computes tf for each word
    for term in TF_dict:
        TF_dict[term] = TF_dict[term] / len(document)
    return TF_dict

pf["TF_dict"] = pf['tokenized_Content'].apply(calc_TF)

pf["TF_dict"].head()
# Out:
# 0                                      {'"good"': 1.0}
# 1    {'"Semoga"': 0.25, '"kedepannya"': 0.25, '"leb...
# 2    {'"Pliss"': 0.07692307692307693, '"ini"': 0.07...
# 3                     {'"Jelek"': 0.5, '"skali"': 0.5}
# 4    {'"Aplikasi"': 0.012987012987012988, '"jelek"'...
# Name: TF_dict, dtype: object

# %%
tf_dict = pf["TF_dict"]

# Membuat list kosong untuk menampung hasil
results = []

# Mengiterasi setiap key dan value dalam tf_dict
for key, value in tf_dict.items():
    results.append({'term': key, 'TF': value})

# Membuat dataframe dari hasil
result_df = pd.DataFrame(results)

# Menampilkan dataframe
result_df
# Out:
#         term                                                 TF
# 0          0                                    {'"good"': 1.0}
# 1          1  {'"Semoga"': 0.25, '"kedepannya"': 0.25, '"leb...
# 2          2  {'"Pliss"': 0.07692307692307693, '"ini"': 0.07...
# 3          3                   {'"Jelek"': 0.5, '"skali"': 0.5}
# 4          4  {'"Aplikasi"': 0.012987012987012988, '"jelek"'...
# ...      ...                                                ...
# 19900  19900  {'"Pemilu"': 0.07692307692307693, '"h-3"': 0.0...
# 19901  19901  {'"Semoga"': 0.09090909090909091, '"Tambah"': ...
# 19902  19902                                    {'"Mbuh"': 1.0}
# 19903  19903  {'"Semoga"': 0.0625, '"tidak"': 0.0625, '"sepe...
# 19904  19904  {'"Semoga"': 0.07142857142857142, '"dengan"': ...
#
# [19905 rows x 2 columns]

# %%
def calc_DF(tfDict):
    count_DF = {}
    for document in tfDict:
        for term in document:
            if term in count_DF:
                count_DF[term] += 1
            else:
                count_DF[term] = 1
    return count_DF

DF = calc_DF(pf["TF_dict"])

# Membuat list kosong untuk menampung hasil
results = []

# Mengiterasi setiap term dan DF dalam DF
for term, doc_freq in DF.items():
    results.append({'term': term, 'DF': doc_freq})

# Membuat dataframe dari hasil
result_df = pd.DataFrame(results)

# Menampilkan dataframe
result_df
# Out:
#                    term   DF
# 0                "good"   22
# 1              "Semoga"  243
# 2          "kedepannya"   47
# 3               "lebih"  577
# 4                "baik"  439
# ...                 ...  ...
# 19319      "25-01-2024"    1
# 19320   "pelantikannya"    1
# 19321          "Semaki"    1
# 19322          ",dunia"    1
# 19323  "Terimakasih💯💯💯"    1
#
# [19324 rows x 2 columns]

# %%
def calc_IDF(n_document, DF):
    IDF_Dict = {}
    for term in DF:
        IDF_Dict[term] = np.log(n_document / (DF[term] + 1))
    return IDF_Dict

# Hitung IDF
IDF = calc_IDF(len(pf), DF)

# code untuk menghitung TF-IDF
def calc_TF_IDF(TF):
    TF_IDF_Dict = {}
    for key in TF:
        TF_IDF_Dict[key] = TF[key] * IDF[key]
    return TF_IDF_Dict

# Set perhitungan TF-IDF untuk membuat kolom "TF-IDF_dict"
pf["TF-IDF_dict"] = pf["TF_dict"].apply(calc_TF_IDF)

results = []

for key, value in pf["TF-IDF_dict"].items():
    row = {"term": key, "TF-IDF": value}
    results.append(row)

# buat hasil dalam dataframe
result_df = pd.DataFrame(results)

# masukan hasil TF ke dataframe
result_df["TF"] = result_df["term"].apply(lambda x: pf["TF_dict"][x])
result_df = result_df[["term", "TF", "TF-IDF"]]
result_df
# Out:
#         term                                                 TF  \
# 0          0                                    {'"good"': 1.0}
# 1          1  {'"Semoga"': 0.25, '"kedepannya"': 0.25, '"leb...
# 2          2  {'"Pliss"': 0.07692307692307693, '"ini"': 0.07...
# 3          3                   {'"Jelek"': 0.5, '"skali"': 0.5}
# 4          4  {'"Aplikasi"': 0.012987012987012988, '"jelek"'...
# ...      ...                                                ...
# 19900  19900  {'"Pemilu"': 0.07692307692307693, '"h-3"': 0.0...
# 19901  19901  {'"Semoga"': 0.09090909090909091, '"Tambah"': ...
# 19902  19902                                    {'"Mbuh"': 1.0}
# 19903  19903  {'"Semoga"': 0.0625, '"tidak"': 0.0625, '"sepe...
# 19904  19904  {'"Semoga"': 0.07142857142857142, '"dengan"': ...
#
#                                                   TF-IDF
# 0                          {'"good"': 6.763232019505268}
# 1      {'"Semoga"': 1.1003895025353039, '"kedepannya"...
# 2      {'"Pliss"': 0.6236128281697202, '"ini"': 0.145...
# 3      {'"Jelek"': 2.651803192649914, '"skali"': 3.70...
# 4      {'"Aplikasi"': 0.02551390911555968, '"jelek"':...
# ...                                                  ...
# 19900  {'"Pemilu"': 0.3744837164647679, '"h-3"': 0.65...
# 19901  {'"Semoga"': 0.40014163728556507, '"Tambah"': ...
# 19902                      {'"Mbuh"': 8.800113946766308}
# 19903  {'"Semoga"': 0.27509737563382597, '"tidak"': 0...
# 19904  {'"Semoga"': 0.31439700072437254, '"dengan"': ...
#
# [19905 rows x 3 columns]
